# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import folium
import streamlit as st
conn = sqlite3.connect('soil_test_database')
c = conn.cursor()

c.execute('''  
SELECT * 
FROM soil_wetness
          ''')
wetness = pd.DataFrame(c.fetchall(),columns=['YEAR','JAN','FEB', 'MAR', 'APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC','ANN','Name'])
wetness
# Out:
#      YEAR   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  \
# 0    2011  0.80  0.80  0.86  0.84  0.70  0.58  0.48  0.29  0.17  0.44  0.48
# 1    2012  0.51  0.55  0.62  0.69  0.53  0.42  0.23  0.16  0.13  0.24  0.50
# 2    2013  0.82  0.77  0.69  0.57  0.46  0.26  0.17  0.15  0.22  0.23  0.30
# 3    2014  0.46  0.53  0.60  0.57  0.48  0.27  0.17  0.14  0.20  0.27  0.48
# 4    2015  0.83  0.82  0.73  0.59  0.50  0.41  0.21  0.16  0.14  0.20  0.49
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 633  2017  0.73  0.84  0.80  0.65  0.46  0.27  0.10  0.09  0.12  0.16  0.33
# 634  2018  0.46  0.45  0.53  0.51  0.38  0.18  0.11  0.09  0.09  0.14  0.23
# 635  2019  0.59  0.74  0.73  0.57  0.46  0.32  0.12  0.09  0.09  0.09  0.13
# 636  2020  0.55  0.51  0.49  0.49  0.38  0.17  0.09  0.09  0.08  0.08  0.27
# 637  2021  0.45  0.56  0.52  0.43  0.24  0.12  0.09  0.08  0.08  0.23  0.44
#
#       DEC   ANN     Name
# 0    0.48  0.58  Alameda
# ...

# %%
wetness = wetness[["YEAR",'ANN','Name']]

# %% [markdown]
# Alpine, Amador, Calaveras, Madera, Mariposa, Merced, Mono, San Joaquin, Stanislaus, Tuolumne

# %%
df = wetness.loc[wetness['Name']=='Alpine']
df1 = wetness.loc[wetness['Name']=='Amador']
df2 = wetness.loc[wetness['Name']=='Calaveras']
df3 = wetness.loc[wetness['Name']=='Madera']
df4 = wetness.loc[wetness['Name']=='Mariposa']
df5 = wetness.loc[wetness['Name']=='Merced']
df6 = wetness.loc[wetness['Name']=='Mono']
df7 = wetness.loc[wetness['Name']=='San Joaquin,']
df8 = wetness.loc[wetness['Name']=='Stanislaus']
df9 = wetness.loc[wetness['Name']=='Tuolumne']

# %%
df1
# Out:
#      YEAR   ANN    Name
# 572  2011  0.62  Amador
# 573  2012  0.48  Amador
# 574  2013  0.48  Amador
# 575  2014  0.47  Amador
# 576  2015  0.48  Amador
# 577  2016  0.60  Amador
# 578  2017  0.60  Amador
# 579  2018  0.51  Amador
# 580  2019  0.58  Amador
# 581  2020  0.45  Amador
# 582  2021  0.48  Amador

# %%
plt.plot(df['YEAR'],df['ANN'])
plt.plot(df1['YEAR'],df['ANN'])
plt.plot(df2['YEAR'],df['ANN'])
plt.plot(df3['YEAR'],df['ANN'])
plt.plot(df4['YEAR'],df['ANN'])
plt.plot(df5['YEAR'],df['ANN'])
plt.plot(df6['YEAR'],df['ANN'])
plt.plot(df7['YEAR'],df['ANN'])
plt.plot(df8['YEAR'],df['ANN'])
plt.plot(df9['YEAR'],df['ANN'])

# %%
plt.plot(df2['YEAR'],df['ANN'])
