# %%
Alamedadf =pd.read_csv('Data/AlmedaMIDPoint.csv')
Alpinedf =pd.read_csv('Data/AlpineMIDPoint.csv')
Humboldtdf =pd.read_csv('Data/HumboltMIDPoint.csv')
Lakedf =pd.read_csv('Data/LakeMIDPoint.csv')
LosAngelesdf =pd.read_csv('Data/LosAngelesMIDPoint.csv')
Nevadadf =pd.read_csv('Data/NevadaMIDPoint.csv')
SanMateodf =pd.read_csv('Data/SanMateoMIDPoint.csv')
SantaClaradf =pd.read_csv('Data/SantaClaraMIDPoint.csv')
Yubadf =pd.read_csv('Data/YubaMIDPoint.csv')
Mendocinodf =pd.read_csv('Data/MendocinoMIDPoint.csv')
Monodf =pd.read_csv('Data/MonoMIDPoint.csv')
Riversidedf =pd.read_csv('Data/RiversideMIDPoint.csv')
SanBenitodf =pd.read_csv('Data/SanBenitoMIDPoint.csv')
SanLuisObispodf =pd.read_csv('Data/SanLuisObisboMIDPoint.csv')
SantaBarbaradf =pd.read_csv('Data/SantaBarbaraMIDPoint.csv')
Sutterdf =pd.read_csv('Data/SutterMIDPoint.csv')
Tularedf =pd.read_csv('Data/TulareMIDPoint.csv')
Buttedf =pd.read_csv('Data/ButteMIDPoint.csv')
Solanodf =pd.read_csv('Data/SolanoMIDPoint.csv')
Calaverasdf =pd.read_csv('Data/CalaverasMIDPoint.csv')
Colusadf =pd.read_csv('Data/ColusaMIDPoint.csv')
Montereydf =pd.read_csv('Data/MontereyMIDPoint.csv')
Stanislausdf =pd.read_csv('Data/StanislausMIDPoint.csv')
SanBernardinodf =pd.read_csv('Data/SanBernardinoMIDPoint.csv')
DelNortedf =pd.read_csv('Data/DelNorteMIDPoint.csv')
Plumasdf =pd.read_csv('Data/PlumasMIDPoint.csv')
Shastadf =pd.read_csv('Data/ShastaMIDPoint.csv')
Siskiyoudf =pd.read_csv('Data/SiskiyouMIDPoint.csv')
Marindf =pd.read_csv('Data/MarinMIDPoint.csv')
SanJoaquindf =pd.read_csv('Data/SanJoaquinMIDPoint.csv')
ContraCostadf =pd.read_csv('Data/ContraCostaMIDPoint.csv')
Glenndf =pd.read_csv('Data/GlennMIDPoint.csv')
Imperialdf =pd.read_csv('Data/ImperialMIDPoint.csv')
Placerdf =pd.read_csv('Data/PlacerMIDPoint.csv')
Kingsdf =pd.read_csv('Data/KingsMIDPoint.csv')
Lassendf =pd.read_csv('Data/LassenMIDPoint.csv')
Tuolumnedf =pd.read_csv('Data/TuolumneMIDPoint.csv')
SanFranciscodf =pd.read_csv('Data/SanFranciscoMIDPoint.csv')
Fresnodf =pd.read_csv('Data/FresnoMIDPoint.csv')
Modocdf =pd.read_csv('Data/ModocMIDPoint.csv')
SantaCruzdf =pd.read_csv('Data/SantaCruzMIDPoint.csv')
Tehamadf =pd.read_csv('Data/TehamaMIDPoint.csv')
Venturadf =pd.read_csv('Data/VenturaMIDPoint.csv')
SanDiegodf =pd.read_csv('Data/SanDiegoMIDPoint.csv')
Kerndf =pd.read_csv('Data/KernMIDPoint.csv')
ElDoradodf =pd.read_csv('Data/ElDoradoMIDPoint.csv')
Sierradf =pd.read_csv('Data/SierraMIDPoint.csv')
Orangedf =pd.read_csv('Data/OrangeMIDPoint.csv')
Yolodf =pd.read_csv('Data/YoloMIDPoint.csv')
Trinitydf =pd.read_csv('Data/TrinityMIDPoint.csv')
Maderadf =pd.read_csv('Data/MaderaMIDPoint.csv')
Inyodf =pd.read_csv('Data/InyoMIDPoint.csv')
Amadordf =pd.read_csv('Data/AmadorMIDPoint.csv')
Sacramentodf =pd.read_csv('Data/SacramentoMIDPoint.csv')
Napadf =pd.read_csv('Data/NapaMIDPoint.csv')
Sonomadf =pd.read_csv('Data/SonomaMIDPoint.csv')
Mariposadf =pd.read_csv('Data/MariposaMIDPoint.csv')
Merceddf = pd.read_csv('Data/MercedMIDPoint.csv')

# %%
Alamedadf,
Alpinedf,
Humboldtdf,
Lakedf,
LosAngelesdf,
Nevadadf,
SanMateodf,
SantaClaradf,
Yubadf,
Mendocinodf,
Monodf,
Riversidedf,
SanBenitodf,
SanLuisObispodf,
SantaBarbaradf,
Sutterdf,
Tularedf,
Buttedf,
Solanodf,
Calaverasdf,
Colusadf,
Montereydf,
Stanislausdf,
SanBernardinodf,
DelNortedf,
Plumasdf,
Shastadf,
Siskiyoudf,
Marindf,
SanJoaquindf,
ContraCostadf,
Glenndf,
Imperialdf,
Placerdf,
Kingsdf,
Lassendf,
Tuolumnedf,
SanFranciscodf,
Fresnodf,
Modocdf,
SantaCruzdf,
Tehamadf,
Venturadf,
SanDiegodf,
Kerndf,
ElDoradodf,
Sierradf,
Orangedf,
Yolodf,
Trinitydf,
Maderadf,
Inyodf,
Amadordf,
Sacramentodf,
Napadf,
Sonomadf,
Mariposadf,
Merceddf

# %%
Alamedadf['Name'] = 'Alameda'
Alpinedf['Name'] = 'Alpine'
Humboldtdf['Name'] = 'Humboldt'
Lakedf['Name'] = 'Lake'
LosAngelesdf['Name'] = 'Los Angeles'
Nevadadf['Name'] = 'Nevada'
SanMateodf['Name'] = 'San Mateo'
SantaClaradf['Name'] = 'Santa Clara'
Yubadf['Name'] = 'Yuba'
Mendocinodf['Name'] = 'Mendocino'
Monodf['Name'] = 'Mono'
Riversidedf['Name'] = 'Riverside'
SanBenitodf['Name'] = 'San Benito'
SanLuisObispodf['Name'] = 'San Luis Obispo'
SantaBarbaradf['Name'] = 'Santa Barbara'
Sutterdf['Name'] = 'Sutter'
Tularedf['Name'] = 'Tulare'
Buttedf['Name'] = 'Butte'
Solanodf['Name'] = 'Solano'
Calaverasdf['Name'] = 'Calaveras'
Colusadf['Name'] = 'Colusa'
Montereydf['Name'] = 'Monterey'
Stanislausdf['Name'] = 'Stanislaus'
SanBernardinodf['Name'] = 'San Bernardino'
DelNortedf['Name'] = 'Del Norte'
Plumasdf['Name'] = 'Plumas'
Shastadf['Name'] = 'Shasta'
Siskiyoudf['Name'] = 'Siskiyou'
Marindf['Name'] = 'Marin'
SanJoaquindf['Name'] = 'San Joaquin'
ContraCostadf['Name'] = 'Contra Costa'
Glenndf['Name'] = 'Glenn'
Imperialdf['Name'] = 'Imperial'
Placerdf['Name'] = 'Placer'
Kingsdf['Name'] = 'Kings'
Lassendf['Name'] = 'Lassen'
Tuolumnedf['Name'] = 'Tuolumne'
SanFranciscodf['Name'] = 'San Francisco'
Fresnodf['Name'] = 'Fresno'
Modocdf['Name'] = 'Modoc'
SantaCruzdf['Name'] = 'Santa Cruz'
Tehamadf['Name'] = 'Tehama'
Venturadf['Name'] = 'Ventura'
SanDiegodf['Name'] = 'San Diego'
Kerndf['Name'] = 'Kern'
ElDoradodf['Name'] = 'El Dorado'
Sierradf['Name'] = 'Sierra'
Orangedf['Name'] = 'Orange'
Yolodf['Name'] = 'Yolo'
Trinitydf['Name'] = 'Trinity'
Maderadf['Name'] = 'Madera'
Inyodf['Name'] = 'Inyo'
Amadordf['Name'] = 'Amador'
Sacramentodf['Name'] = 'Sacramento'
Napadf['Name'] = 'Napa'
Sonomadf['Name'] = 'Sonoma'
Mariposadf['Name'] = 'Mariposa'
Merceddf['Name'] = 'Merced'

Alamedadf = Alamedadf.loc[:,'YEAR':'Name']
Alpinedf = Alpinedf.loc[:,'YEAR':'Name']
Humboldtdf = Humboldtdf.loc[:,'YEAR':'Name']
Lakedf = Lakedf.loc[:,'YEAR':'Name']
LosAngelesdf = LosAngelesdf.loc[:,'YEAR':'Name']
Nevadadf = Nevadadf.loc[:,'YEAR':'Name']
SanMateodf = SanMateodf.loc[:,'YEAR':'Name']
Santadf = Claradf = SantaClaradf.loc[:,'YEAR':'Name']
Yubadf = Yubadf.loc[:,'YEAR':'Name']
Mendocinodf = Mendocinodf.loc[:,'YEAR':'Name']
Monodf = Monodf.loc[:,'YEAR':'Name']
Riversidedf = Riversidedf.loc[:,'YEAR':'Name']
SanBenitodf = SanBenitodf.loc[:,'YEAR':'Name']
SanLuisObispodf = SanLuisObispodf.loc[:,'YEAR':'Name']
SantaBarbaradf = SantaBarbaradf.loc[:,'YEAR':'Name']
Sutterdf = Sutterdf.loc[:,'YEAR':'Name']
Tularedf = Tularedf.loc[:,'YEAR':'Name']
Buttedf = Buttedf.loc[:,'YEAR':'Name']
Solanodf = Solanodf.loc[:,'YEAR':'Name']
Calaverasdf = Calaverasdf.loc[:,'YEAR':'Name']
Colusadf = Colusadf.loc[:,'YEAR':'Name']
Montereydf = Montereydf.loc[:,'YEAR':'Name']
Stanislausdf = Stanislausdf.loc[:,'YEAR':'Name']
SanBernardinodf = SanBernardinodf.loc[:,'YEAR':'Name']
DelNortedf = DelNortedf.loc[:,'YEAR':'Name']
Plumasdf = Plumasdf.loc[:,'YEAR':'Name']
Shastadf = Shastadf.loc[:,'YEAR':'Name']
Siskiyoudf = Siskiyoudf.loc[:,'YEAR':'Name']
Marindf = Marindf.loc[:,'YEAR':'Name']
SanJoaquindf = SanJoaquindf.loc[:,'YEAR':'Name']
ContraCostadf = ContraCostadf.loc[:,'YEAR':'Name']
Glenndf = Glenndf.loc[:,'YEAR':'Name']
Imperialdf = Imperialdf.loc[:,'YEAR':'Name']
Placerdf = Placerdf.loc[:,'YEAR':'Name']
Kingsdf = Kingsdf.loc[:,'YEAR':'Name']
Lassendf = Lassendf.loc[:,'YEAR':'Name']
Tuolumnedf = Tuolumnedf.loc[:,'YEAR':'Name']
SanFranciscodf = SanFranciscodf.loc[:,'YEAR':'Name']
Fresnodf = Fresnodf.loc[:,'YEAR':'Name']
Modocdf = Modocdf.loc[:,'YEAR':'Name']
SantaCruzdf = SantaCruzdf.loc[:,'YEAR':'Name']
Tehamadf = Tehamadf.loc[:,'YEAR':'Name']
Venturadf = Venturadf.loc[:,'YEAR':'Name']
SanDiegodf = SanDiegodf.loc[:,'YEAR':'Name']
Kerndf = Kerndf.loc[:,'YEAR':'Name']
ElDoradodf = ElDoradodf.loc[:,'YEAR':'Name']
Sierradf = Sierradf.loc[:,'YEAR':'Name']
Orangedf = Orangedf.loc[:,'YEAR':'Name']
Yolodf = Yolodf.loc[:,'YEAR':'Name']
Trinitydf = Trinitydf.loc[:,'YEAR':'Name']
Maderadf = Maderadf.loc[:,'YEAR':'Name']
Inyodf = Inyodf.loc[:,'YEAR':'Name']
Amadordf = Amadordf.loc[:,'YEAR':'Name']
Sacramentodf = Sacramentodf.loc[:,'YEAR':'Name']
Napadf = Napadf.loc[:,'YEAR':'Name']
Sonomadf = Sonomadf.loc[:,'YEAR':'Name']
Mariposadf = Mariposadf.loc[:,'YEAR':'Name']
Merceddf = Merceddf.loc[:,'YEAR':'Name']


counties = [Alamedadf,Alpinedf,
Humboldtdf,
Lakedf,
LosAngelesdf,
Nevadadf,
SanMateodf,
SantaClaradf,
Yubadf,
Mendocinodf,
Monodf,
Riversidedf,
SanBenitodf,
SanLuisObispodf,
SantaBarbaradf,
Sutterdf,
Tularedf,
Buttedf,
Solanodf,
Calaverasdf,
Colusadf,
Montereydf,
Stanislausdf,
SanBernardinodf,
DelNortedf,
Plumasdf,
Shastadf,
Siskiyoudf,
Marindf,
SanJoaquindf,
ContraCostadf,
Glenndf,
Imperialdf,
Placerdf,
Kingsdf,
Lassendf,
Tuolumnedf,
SanFranciscodf,
Fresnodf,
Modocdf,
SantaCruzdf,
Tehamadf,
Venturadf,
SanDiegodf,
Kerndf,
ElDoradodf,
Sierradf,
Orangedf,
Yolodf,
Trinitydf,
Maderadf,
Inyodf,
Amadordf,
Sacramentodf,
Napadf,
Sonomadf,
Mariposadf,
Merceddf]

data = pd.concat(counties)
data = data.loc[:, 'YEAR':'Name']

# %%
data
# Out:
#     YEAR   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  \
# 0   2011  0.80  0.80  0.86  0.84  0.70  0.58  0.48  0.29  0.17  0.44  0.48
# 1   2012  0.51  0.55  0.62  0.69  0.53  0.42  0.23  0.16  0.13  0.24  0.50
# 2   2013  0.82  0.77  0.69  0.57  0.46  0.26  0.17  0.15  0.22  0.23  0.30
# 3   2014  0.46  0.53  0.60  0.57  0.48  0.27  0.17  0.14  0.20  0.27  0.48
# 4   2015  0.83  0.82  0.73  0.59  0.50  0.41  0.21  0.16  0.14  0.20  0.49
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 6   2017  0.73  0.84  0.80  0.65  0.46  0.27  0.10  0.09  0.12  0.16  0.33
# 7   2018  0.46  0.45  0.53  0.51  0.38  0.18  0.11  0.09  0.09  0.14  0.23
# 8   2019  0.59  0.74  0.73  0.57  0.46  0.32  0.12  0.09  0.09  0.09  0.13
# 9   2020  0.55  0.51  0.49  0.49  0.38  0.17  0.09  0.09  0.08  0.08  0.27
# 10  2021  0.45  0.56  0.52  0.43  0.24  0.12  0.09  0.08  0.08  0.23  0.44
#
#      DEC   ANN     Name
# 0   0.48  0.58  Alameda
# ...

# %%
import geopandas as gpd
def read_file(path):
    return gpd.read_file(path)
geodata = read_file('county_ca.geojson')

# %%
geodata
# Out:
#    STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID             NAME LSAD  \
# 0       06      001  01675839  0500000US06001  06001          Alameda   06
# 1       06      003  01675840  0500000US06003  06003           Alpine   06
# 2       06      023  01681908  0500000US06023  06023         Humboldt   06
# 3       06      033  00277281  0500000US06033  06033             Lake   06
# 4       06      037  00277283  0500000US06037  06037      Los Angeles   06
# 5       06      057  01682927  0500000US06057  06057           Nevada   06
# 6       06      081  00277305  0500000US06081  06081        San Mateo   06
# 7       06      085  00277307  0500000US06085  06085      Santa Clara   06
# 8       06      115  00277322  0500000US06115  06115             Yuba   06
# 9       06      045  00277287  0500000US06045  06045        Mendocino   06
# 10      06      051  00277290  0500000US06051  06051             Mono   06
# ...

# %%
names= list(geodata['NAME'])
names#names['name_dup'] = names.loc['Names']
# Out:
# ['Alameda',
#  'Alpine',
#  'Humboldt',
#  'Lake',
#  'Los Angeles',
#  'Nevada',
#  'San Mateo',
#  'Santa Clara',
#  'Yuba',
#  'Mendocino',
#  'Mono',
#  'Riverside',
#  'San Benito',
#  'San Luis Obispo',
#  'Santa Barbara',
#  'Sutter',
#  'Tulare',
#  'Butte',
#  'Solano',
#  'Calaveras',
#  'Colusa',
#  'Monterey',
#  'Stanislaus',
#  'San Bernardino',
#  'Del Norte',
#  'Plumas',
#  'Shasta',
#  'Siskiyou',
#  'Marin',
#  'San Joaquin',
#  'Contra Costa',
#  'Glenn',
#  'Imperial',
#  'Placer',
#  'Kings',
#  'Lassen',
#  'Tuolumne',
#  'San Francisco',
#  'Fresno',
#  'Modoc',
#  'Santa Cruz',
#  'Tehama',
#  'Ventura',
#  'San Diego',
#  'Kern',
#  'El Dorado',
#  'Sierra',
#  'Orange',
#  'Yolo',
#  'Trinity',
#  'Madera',
#  'Inyo',
#  'Amador',
#  'Sacramento',
#  'Napa',
#  'Sonoma',
#  'Mariposa',
#  'Merced']

# %%
countydf = geodata.merge(data,left_on ='NAME', right_on = 'Name', how ='outer')
countydf = countydf[['COUNTYFP', 'Name']]

countydf = countydf.drop_duplicates(subset = ["COUNTYFP", "Name"],keep='first')
countydf = countydf.dropna()
countydf
# Out:
#     COUNTYFP             Name
# 0        001          Alameda
# 11       003           Alpine
# 22       023         Humboldt
# 33       033             Lake
# 44       037      Los Angeles
# 55       057           Nevada
# 66       081        San Mateo
# 77       085      Santa Clara
# 88       115             Yuba
# 99       045        Mendocino
# 110      051             Mono
# 121      065        Riverside
# 132      069       San Benito
# 143      079  San Luis Obispo
# 154      083    Santa Barbara
# 165      101           Sutter
# 176      107           Tulare
# 187      007            Butte
# 198      095           Solano
# 209      009        Calaveras
# 220      011           Colusa
# 231      053         Monterey
# 242      099       Stanislaus
# 253      071   San Bernardino
# 264      015        Del Norte
# 275      063           Plumas
# 286      089           Shasta
# 297      093         Siskiyou
# 308      041            Marin
# 319      077      San Joaquin
# ...

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('soil_test_database')
c = conn.cursor()

c.execute('CREATE TABLE IF NOT EXISTS counties (countyfp number, Name text)')
conn.commit()

c.execute('CREATE TABLE IF NOT EXISTS soil_wetness (YEAR number, JAN number, FEB number, MAR number, APR number, MAY number, JUN number, JUL number, AUG number, SEP number, OCT number, NOV number, DEC number, ANN number, Name text)')
conn.commit()

data.to_sql('soil_wetness', conn, if_exists='replace', index = False)


#c.execute('CREATE TABLE IF NOT EXISTS counties (countyfp number, Name text,PRIMARY_KEY(countyfp))')
#conn.commit()



countydf.to_sql('counties', conn, if_exists='replace', index = False)
# Out:
# 58

# %%
c.execute('''  
SELECT * 
FROM soil_wetness
          ''')
wetness = pd.DataFrame(c.fetchall(),columns=['YEAR','JAN','FEB', 'MAR', 'APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC','ANN','Name'])
wetness.head()
# Out:
#    YEAR   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  \
# 0  2011  0.80  0.80  0.86  0.84  0.70  0.58  0.48  0.29  0.17  0.44  0.48
# 1  2012  0.51  0.55  0.62  0.69  0.53  0.42  0.23  0.16  0.13  0.24  0.50
# 2  2013  0.82  0.77  0.69  0.57  0.46  0.26  0.17  0.15  0.22  0.23  0.30
# 3  2014  0.46  0.53  0.60  0.57  0.48  0.27  0.17  0.14  0.20  0.27  0.48
# 4  2015  0.83  0.82  0.73  0.59  0.50  0.41  0.21  0.16  0.14  0.20  0.49
#
#     DEC   ANN     Name
# 0  0.48  0.58  Alameda
# 1  0.76  0.45  Alameda
# 2  0.48  0.42  Alameda
# 3  0.79  0.41  Alameda
# 4  0.59  0.47  Alameda

# %%
c.execute('''  
SELECT * 
FROM counties
          ''')

countydf = pd.DataFrame(c.fetchall(),columns=['county_fips_id','county_name'])

# %%
countydf
# Out:
#    county_fips_id      county_name
# 0             001          Alameda
# 1             003           Alpine
# 2             023         Humboldt
# 3             033             Lake
# 4             037      Los Angeles
# 5             057           Nevada
# 6             081        San Mateo
# 7             085      Santa Clara
# 8             115             Yuba
# 9             045        Mendocino
# 10            051             Mono
# 11            065        Riverside
# 12            069       San Benito
# 13            079  San Luis Obispo
# 14            083    Santa Barbara
# 15            101           Sutter
# 16            107           Tulare
# 17            007            Butte
# 18            095           Solano
# 19            009        Calaveras
# 20            011           Colusa
# 21            053         Monterey
# 22            099       Stanislaus
# 23            071   San Bernardino
# 24            015        Del Norte
# 25            063           Plumas
# ...
