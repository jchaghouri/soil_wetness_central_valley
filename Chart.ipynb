# %%
import geopandas as gpd
import matplotlib.pyplot as plt 
import csv
import pandas as pd 
from numpy import loadtxt
import streamlit as st
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
import numpy as np
import sys
from matplotlib import colors #import 
import scipy.optimize as optimize

# %%
Mercedset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Merced County\MercedMIDPoint.csv")
Sacset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Sac County\SacramentoMIDPoint.csv")
SanJset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\San Joaqin County\SanJoaquinMIDPoint.csv")
Solanoset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Solano County\SolanoMIDPoint.csv")
Stanset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Stanislaus County\StanislausMIDPoint.csv")
Yoloset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Yolo County\YoloMIDPoint.csv")

# %%
x = Mercedset.loc[:,'JAN':'DEC']
x
# Out:
#      JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV   DEC
# 0   0.71  0.69  0.73  0.66  0.48  0.41  0.20  0.10  0.09  0.34  0.40  0.38
# 1   0.38  0.45  0.47  0.49  0.37  0.21  0.11  0.09  0.08  0.16  0.37  0.57
# 2   0.64  0.59  0.51  0.43  0.25  0.12  0.09  0.09  0.11  0.16  0.27  0.39
# 3   0.30  0.44  0.47  0.44  0.28  0.12  0.09  0.09  0.10  0.15  0.42  0.55
# 4   0.55  0.54  0.48  0.40  0.32  0.16  0.12  0.12  0.10  0.23  0.45  0.49
# 5   0.62  0.65  0.65  0.55  0.44  0.22  0.10  0.08  0.08  0.23  0.45  0.51
# 6   0.73  0.84  0.80  0.65  0.46  0.27  0.10  0.09  0.12  0.16  0.33  0.39
# 7   0.46  0.45  0.53  0.51  0.38  0.18  0.11  0.09  0.09  0.14  0.23  0.52
# 8   0.59  0.74  0.73  0.57  0.46  0.32  0.12  0.09  0.09  0.09  0.13  0.55
# 9   0.55  0.51  0.49  0.49  0.38  0.17  0.09  0.09  0.08  0.08  0.27  0.38
# 10  0.45  0.56  0.52  0.43  0.24  0.12  0.09  0.08  0.08  0.23  0.44  0.51

# %%
plt.plot(Mercedset["PARAMETER"],Mercedset.loc[:,'JAN':'DEC'])
# Out:
# [<matplotlib.lines.Line2D at 0x1f019d368e0>,
#  <matplotlib.lines.Line2D at 0x1f0165e5610>,
#  <matplotlib.lines.Line2D at 0x1f019fa2910>,
#  <matplotlib.lines.Line2D at 0x1f01bfb1ac0>,
#  <matplotlib.lines.Line2D at 0x1f01bfb1b20>,
#  <matplotlib.lines.Line2D at 0x1f01bfb1c70>,
#  <matplotlib.lines.Line2D at 0x1f01bfb1d90>,
#  <matplotlib.lines.Line2D at 0x1f01bfb1eb0>,
#  <matplotlib.lines.Line2D at 0x1f01bfb1fd0>,
#  <matplotlib.lines.Line2D at 0x1f01bfc7130>,
#  <matplotlib.lines.Line2D at 0x1f019f7b4c0>,
#  <matplotlib.lines.Line2D at 0x1f01bfc7250>]

# %%
plt.plot(Yoloset["PARAMETER"],Yoloset.loc[:,'JAN':'DEC'])
# Out:
# [<matplotlib.lines.Line2D at 0x1f01d0bbca0>,
#  <matplotlib.lines.Line2D at 0x1f01d0bbc10>,
#  <matplotlib.lines.Line2D at 0x1f01d0bbe20>,
#  <matplotlib.lines.Line2D at 0x1f01d0bbf40>,
#  <matplotlib.lines.Line2D at 0x1f01d0cb0a0>,
#  <matplotlib.lines.Line2D at 0x1f01d0cb1c0>,
#  <matplotlib.lines.Line2D at 0x1f01d0cb2e0>,
#  <matplotlib.lines.Line2D at 0x1f01d0cb400>,
#  <matplotlib.lines.Line2D at 0x1f01d0cb520>,
#  <matplotlib.lines.Line2D at 0x1f01d0cb640>,
#  <matplotlib.lines.Line2D at 0x1f01d096670>,
#  <matplotlib.lines.Line2D at 0x1f01d0cb760>]
