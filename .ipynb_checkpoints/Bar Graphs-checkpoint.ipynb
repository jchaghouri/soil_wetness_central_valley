# %%
import geopandas as gpd
import matplotlib.pyplot as plt 
import csv
import pandas as pd 
from numpy import loadtxt
import streamlit as st
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
import numpy as np
import sys
from matplotlib import colors #import 
import scipy.optimize as optimize

# %%
Mercedset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Merced County\MercedMIDPoint.csv")
Sacset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Sac County\SacramentoMIDPoint.csv")
SanJset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\San Joaqin County\SanJoaquinMIDPoint.csv")
Solanoset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Solano County\SolanoMIDPoint.csv")
Stanset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Stanislaus County\StanislausMIDPoint.csv")
Yoloset = pd.read_csv(r"C:\Users\lalberto2\Documents\Python\Projects\soil_wetness_central_valley\Data\Yolo County\YoloMIDPoint.csv")

# %%
x = Mercedset["YEAR"]

# %%
fig, axs = plt.subplots(3, 4,figsize = (15,15))
axs[0, 0].bar(x, Mercedset["JAN"])
axs[0, 0].set_title('January Soil Wetness  ')

axs[0, 1].bar(x, Mercedset["FEB"])
axs[0, 1].set_title('Febuary Soil Wetness  ')

axs[0, 2].bar(x, Mercedset["MAR"])
axs[0, 2].set_title('March Soil Wetness  ')

axs[0, 3].bar(x, Mercedset["APR"])
axs[0, 3].set_title('April Soil Wetness  ')

axs[1, 0].bar(x, Mercedset["MAY"])
axs[1, 0].set_title('May Soil Wetness  ')

axs[1, 1].bar(x, Mercedset["JUN"])
axs[1, 1].set_title('June Soil Wetness  ')

axs[1, 2].bar(x, Mercedset["JUL"])
axs[1, 2].set_title('July Soil Wetness  ')

axs[1, 3].bar(x, Mercedset["AUG"])
axs[1, 3].set_title('August Soil Wetness  ')

axs[2, 0].bar(x, Mercedset["SEP"])
axs[2, 0].set_title('September Soil Wetness  ')

axs[2, 1].bar(x, Mercedset["OCT"])
axs[2, 1].set_title('October Soil Wetness  ')

axs[2, 2].bar(x, Mercedset["NOV"])
axs[2, 2].set_title('November Soil Wetness  ')

axs[2, 3].bar(x, Mercedset["DEC"])
axs[2, 3].set_title('December Soil Wetness  ')

for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Soil Wetness')
    ax.set(ylim = (0,1))
# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
    #ax.label_outer()

# %%
fig, axs = plt.subplots(3, 4,figsize = (15,15))
axs[0, 0].bar(x, Sacset["JAN"])
axs[0, 0].set_title('January Soil Wetness  ')

axs[0, 1].bar(x, Sacset["FEB"])
axs[0, 1].set_title('Febuary Soil Wetness  ')

axs[0, 2].bar(x, Sacset["MAR"])
axs[0, 2].set_title('March Soil Wetness  ')

axs[0, 3].bar(x, Sacset["APR"])
axs[0, 3].set_title('April Soil Wetness  ')

axs[1, 0].bar(x, Sacset["MAY"])
axs[1, 0].set_title('May Soil Wetness  ')

axs[1, 1].bar(x, Sacset["JUN"])
axs[1, 1].set_title('June Soil Wetness  ')

axs[1, 2].bar(x, Sacset["JUL"])
axs[1, 2].set_title('July Soil Wetness  ')

axs[1, 3].bar(x, Sacset["AUG"])
axs[1, 3].set_title('August Soil Wetness  ')

axs[2, 0].bar(x, Sacset["SEP"])
axs[2, 0].set_title('September Soil Wetness  ')

axs[2, 1].bar(x, Sacset["OCT"])
axs[2, 1].set_title('October Soil Wetness  ')

axs[2, 2].bar(x, Sacset["NOV"])
axs[2, 2].set_title('November Soil Wetness  ')

axs[2, 3].bar(x, Sacset["DEC"])
axs[2, 3].set_title('December Soil Wetness  ')

for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Soil Wetness')
    ax.set(ylim = (0,1))
# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
    #ax.label_outer()

# %%
fig, axs = plt.subplots(3, 4,figsize = (15,15))
axs[0, 0].bar(x, SanJset["JAN"])
axs[0, 0].set_title('January Soil Wetness  ')

axs[0, 1].bar(x, SanJset["FEB"])
axs[0, 1].set_title('Febuary Soil Wetness  ')

axs[0, 2].bar(x, SanJset["MAR"])
axs[0, 2].set_title('March Soil Wetness  ')

axs[0, 3].bar(x, SanJset["APR"])
axs[0, 3].set_title('April Soil Wetness  ')

axs[1, 0].bar(x, SanJset["MAY"])
axs[1, 0].set_title('May Soil Wetness  ')

axs[1, 1].bar(x, SanJset["JUN"])
axs[1, 1].set_title('June Soil Wetness  ')

axs[1, 2].bar(x, SanJset["JUL"])
axs[1, 2].set_title('July Soil Wetness  ')

axs[1, 3].bar(x, SanJset["AUG"])
axs[1, 3].set_title('August Soil Wetness  ')

axs[2, 0].bar(x, SanJset["SEP"])
axs[2, 0].set_title('September Soil Wetness  ')

axs[2, 1].bar(x, SanJset["OCT"])
axs[2, 1].set_title('October Soil Wetness  ')

axs[2, 2].bar(x, SanJset["NOV"])
axs[2, 2].set_title('November Soil Wetness  ')

axs[2, 3].bar(x, SanJset["DEC"])
axs[2, 3].set_title('December Soil Wetness  ')

for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Soil Wetness')
    ax.set(ylim = (0,1))
# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
    #ax.label_outer()

# %%
fig, axs = plt.subplots(3, 4,figsize = (15,15))
axs[0, 0].bar(x, Solanoset["JAN"])
axs[0, 0].set_title('January Soil Wetness  ')

axs[0, 1].bar(x, Solanoset["FEB"])
axs[0, 1].set_title('Febuary Soil Wetness  ')

axs[0, 2].bar(x, Solanoset["MAR"])
axs[0, 2].set_title('March Soil Wetness  ')

axs[0, 3].bar(x, Solanoset["APR"])
axs[0, 3].set_title('April Soil Wetness  ')

axs[1, 0].bar(x, Solanoset["MAY"])
axs[1, 0].set_title('May Soil Wetness  ')

axs[1, 1].bar(x, Solanoset["JUN"])
axs[1, 1].set_title('June Soil Wetness  ')

axs[1, 2].bar(x, Solanoset["JUL"])
axs[1, 2].set_title('July Soil Wetness  ')

axs[1, 3].bar(x, Solanoset["AUG"])
axs[1, 3].set_title('August Soil Wetness  ')

axs[2, 0].bar(x, Solanoset["SEP"])
axs[2, 0].set_title('September Soil Wetness  ')

axs[2, 1].bar(x, Solanoset["OCT"])
axs[2, 1].set_title('October Soil Wetness  ')

axs[2, 2].bar(x, Solanoset["NOV"])
axs[2, 2].set_title('November Soil Wetness  ')

axs[2, 3].bar(x, Solanoset["DEC"])
axs[2, 3].set_title('December Soil Wetness  ')

for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Soil Wetness')
    ax.set(ylim = (0,1))
# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
    #ax.label_outer()

# %%
fig, axs = plt.subplots(3, 4,figsize = (15,15))
axs[0, 0].bar(x, Stanset["JAN"])
axs[0, 0].set_title('January Soil Wetness  ')

axs[0, 1].bar(x, Stanset["FEB"])
axs[0, 1].set_title('Febuary Soil Wetness  ')

axs[0, 2].bar(x, Stanset["MAR"])
axs[0, 2].set_title('March Soil Wetness  ')

axs[0, 3].bar(x, Stanset["APR"])
axs[0, 3].set_title('April Soil Wetness  ')

axs[1, 0].bar(x, Stanset["MAY"])
axs[1, 0].set_title('May Soil Wetness  ')

axs[1, 1].bar(x, Stanset["JUN"])
axs[1, 1].set_title('June Soil Wetness  ')

axs[1, 2].bar(x, Stanset["JUL"])
axs[1, 2].set_title('July Soil Wetness  ')

axs[1, 3].bar(x, Stanset["AUG"])
axs[1, 3].set_title('August Soil Wetness  ')

axs[2, 0].bar(x, Stanset["SEP"])
axs[2, 0].set_title('September Soil Wetness  ')

axs[2, 1].bar(x, Stanset["OCT"])
axs[2, 1].set_title('October Soil Wetness  ')

axs[2, 2].bar(x, Stanset["NOV"])
axs[2, 2].set_title('November Soil Wetness  ')

axs[2, 3].bar(x, Stanset["DEC"])
axs[2, 3].set_title('December Soil Wetness  ')

for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Soil Wetness')
    ax.set(ylim = (0,1))
# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
    #ax.label_outer()

# %%
fig, axs = plt.subplots(3, 4,figsize = (15,15))
axs[0, 0].bar(x, Yoloset["JAN"])
axs[0, 0].set_title('January Soil Wetness  ')

axs[0, 1].bar(x, Yoloset["FEB"])
axs[0, 1].set_title('Febuary Soil Wetness  ')

axs[0, 2].bar(x, Yoloset["MAR"])
axs[0, 2].set_title('March Soil Wetness  ')

axs[0, 3].bar(x, Yoloset["APR"])
axs[0, 3].set_title('April Soil Wetness  ')

axs[1, 0].bar(x, Yoloset["MAY"])
axs[1, 0].set_title('May Soil Wetness  ')

axs[1, 1].bar(x, Yoloset["JUN"])
axs[1, 1].set_title('June Soil Wetness  ')

axs[1, 2].bar(x, Yoloset["JUL"])
axs[1, 2].set_title('July Soil Wetness  ')

axs[1, 3].bar(x, Yoloset["AUG"])
axs[1, 3].set_title('August Soil Wetness  ')

axs[2, 0].bar(x, Yoloset["SEP"])
axs[2, 0].set_title('September Soil Wetness  ')

axs[2, 1].bar(x, Yoloset["OCT"])
axs[2, 1].set_title('October Soil Wetness  ')

axs[2, 2].bar(x, Yoloset["NOV"])
axs[2, 2].set_title('November Soil Wetness  ')

axs[2, 3].bar(x, Yoloset["DEC"])
axs[2, 3].set_title('December Soil Wetness  ')

for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Soil Wetness')
    ax.set(ylim = (0,1))
# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
    #ax.label_outer()
