# %%
import geopandas as gpd
import matplotlib.pyplot as plt 
import csv
import pandas as pd 
from numpy import loadtxt
import streamlit as st
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
import numpy as np
import sys
from matplotlib import colors #import 
import scipy.optimize as optimize

# %%
x = newdf["YEAR"]
fig, axs = plt.subplots(3, 4,figsize = (15,15))
axs[0, 0].bar(x, newdf["January"])
axs[0, 0].set_title('January Soil Wetness  ')

axs[0, 1].bar(x, newdf["February"])
axs[0, 1].set_title('Febuary Soil Wetness  ')

axs[0, 2].bar(x, newdf["March"])
axs[0, 2].set_title('March Soil Wetness  ')

axs[0, 3].bar(x, newdf["April"])
axs[0, 3].set_title('April Soil Wetness  ')

axs[1, 0].bar(x, newdf["May"])
axs[1, 0].set_title('May Soil Wetness  ')

axs[1, 1].bar(x, newdf["June"])
axs[1, 1].set_title('June Soil Wetness  ')

axs[1, 2].bar(x, newdf["July"])
axs[1, 2].set_title('July Soil Wetness  ')

axs[1, 3].bar(x, newdf["August"])
axs[1, 3].set_title('August Soil Wetness  ')

axs[2, 0].bar(x, newdf["September"])
axs[2, 0].set_title('September Soil Wetness  ')

axs[2, 1].bar(x, newdf["October"])
axs[2, 1].set_title('October Soil Wetness  ')

axs[2, 2].bar(x, newdf["November"])
axs[2, 2].set_title('November Soil Wetness  ')

axs[2, 3].bar(x, newdf["December"])
axs[2, 3].set_title('December Soil Wetness  ')

for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Soil Wetness')
    ax.set(ylim = (0,1))
# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
    #ax.label_outer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 fig, axs = plt.subplots(3, 4,figsize = (15,15))
# ----> 2 axs[0, 0].bar(x, Mercedset["JAN"])
#       3 axs[0, 0].set_title('January Soil Wetness  ')
#       5 axs[0, 1].bar(x, Mercedset["FEB"])
#
# NameError: name 'x' is not defined
